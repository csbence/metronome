# %% [markdown]
# # Mo`RTS Evaluation

# %%
# Standard workhorses
import numpy as np
import matplotlib.pyplot as plt

# Metronome
import metronome_plot as mp
from mongo_client import MetronomeMongoClient

# Seaborn, useful for graphics
import seaborn as sns

# Magic function to make matplotlib inline; other style specs must come AFTER
# %matplotlib inline

# This enables SVG graphics inline (only use with static plots (non-Bokeh))
# %config InlineBackend.figure_formats = {'svg',}

# JB's favorite Seaborn settings for notebooks
rc = {'lines.linewidth': 2, 
      'axes.labelsize': 18, 
      'axes.titlesize': 18, 
      'axes.facecolor': 'DFDFE5'}
sns.set_context('notebook', rc=rc)
sns.set_style('white', rc=rc)

#Mongo connection
db = MetronomeMongoClient()

# %%
mp.plot_experiments(db,
    ["A_STAR", "LSS_LRTA_STAR", "MO_RTS", "MO_RTS_OLD"],
    'SLIDING_TILE_PUZZLE',
    '/input/tiles/korf/4/all/',
    'EXPANSIONS',
    'STATIC'
    )
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-f9fe8aa98d56> in <module>()
#       4     '/input/tiles/korf/4/all/',
#       5     'EXPANSIONS',
# ----> 6     'STATIC'
#       7     )
#
# /home/aifs2/group/code/real_time_search/metronome/scripts/metronome_plot.py in plot_experiments(db, algorithms, domain, instance, termination_type, lookahead_type)
#      31
#      32     if len(data) > 0:
# ---> 33         data_frame = construct_data_frame(data)
#      34         plot_data_frame(data_frame)
#      35     else:
#
# /home/aifs2/group/code/real_time_search/metronome/scripts/metronome_plot.py in plot_data_frame(experiments)
#      46
#      47     boxplot = sns.boxplot(x="actionDuration",
# ---> 48                           y="goalAchievementTime",
#      49                           hue="algorithmName",
#      50                           data=experiments,
#
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2173     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2174                           orient, color, palette, saturation,
# -> 2175                           width, fliersize, linewidth)
#    2176
#    2177     if ax is None:
#
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, fliersize, linewidth)
#     424                  width, fliersize, linewidth):
#     425
# --> 426         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     427         self.establish_colors(color, palette, saturation)
#     428
#
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     149                 if isinstance(input, string_types):
#     150                     err = "Could not interpret input '{}'".format(input)
# --> 151                     raise ValueError(err)
#     152
#     153             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'actionDuration'

# %%
mp.plot_experiments(db,
    ["A_STAR", "LSS_LRTA_STAR", "MO_RTS", "MO_RTS_OLD"],
    'GRID_WORLD',
    '/input/vacuum/variants/cups-2/cups_',
    'EXPANSIONS',
    'STATIC'
    )
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-43276b83c892> in <module>()
#       4     '/input/vacuum/variants/cups-2/cups_',
#       5     'EXPANSIONS',
# ----> 6     'STATIC'
#       7     )
#
# /home/aifs2/group/code/real_time_search/metronome/scripts/metronome_plot.py in plot_experiments(db, algorithms, domain, instance, termination_type, lookahead_type)
#      31
#      32     data_frame = construct_data_frame(data)
# ---> 33     if not data_frame.empty:
#      34         plot_data_frame(data_frame)
#      35     else:
#
# /home/aifs2/group/code/real_time_search/metronome/scripts/metronome_plot.py in plot_data_frame(experiments)
#      46
#      47     boxplot = sns.boxplot(x="actionDuration",
# ---> 48                           y="goalAchievementTime",
#      49                           hue="algorithmName",
#      50                           data=experiments,
#
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2173     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2174                           orient, color, palette, saturation,
# -> 2175                           width, fliersize, linewidth)
#    2176
#    2177     if ax is None:
#
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, fliersize, linewidth)
#     424                  width, fliersize, linewidth):
#     425
# --> 426         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     427         self.establish_colors(color, palette, saturation)
#     428
#
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     149                 if isinstance(input, string_types):
#     150                     err = "Could not interpret input '{}'".format(input)
# --> 151                     raise ValueError(err)
#     152
#     153             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'actionDuration'

# %%
mp.plot_experiments(db,
    ["A_STAR", "LSS_LRTA_STAR", "MO_RTS", "MO_RTS_OLD"],
    'GRID_WORLD',
    '/input/vacuum/variants/wall-2/wall_',
    'EXPANSIONS',
    'STATIC'
    )
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-0d10e2195fa2> in <module>()
#       4     '/input/vacuum/variants/wall-2/wall_',
#       5     'EXPANSIONS',
# ----> 6     'STATIC'
#       7     )
#
# /home/aifs2/group/code/real_time_search/metronome/scripts/metronome_plot.py in plot_experiments(db, algorithms, domain, instance, termination_type, lookahead_type)
#      31
#      32     print(construct_data_frame(data))
# ---> 33     plot_data_frame(construct_data_frame(data))
#      34
#      35
#
# /home/aifs2/group/code/real_time_search/metronome/scripts/metronome_plot.py in plot_data_frame(experiments)
#      46                           hue="algorithmName",
#      47                           data=experiments,
# ---> 48                           showmeans=True)
#      49     plt.yscale('log')
#      50     plt.show(boxplot)
#
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2173     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2174                           orient, color, palette, saturation,
# -> 2175                           width, fliersize, linewidth)
#    2176
#    2177     if ax is None:
#
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, fliersize, linewidth)
#     424                  width, fliersize, linewidth):
#     425
# --> 426         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     427         self.establish_colors(color, palette, saturation)
#     428
#
# /usr/local/lib/python3.5/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     149                 if isinstance(input, string_types):
#     150                     err = "Could not interpret input '{}'".format(input)
# --> 151                     raise ValueError(err)
#     152
#     153             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'actionDuration'
